# %% [markdown]
# <a href="https://colab.research.google.com/github/sheikh-mohammad/AI-101-YT-Assigments/blob/main/Class_2/project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1 - Email Writing
#
# In Project 1, I created email program using python.
#
# I used following things in python to create this program.
#
# - f-string
# - variables
# - string
# - print()

# %%
name = "Ebad"

email = f"""Hi {name}
You got a free coupon code.
Best Regards,
Sheikh Mohammad.
"""

print(email)
# Out:
# Hi Ebad
# You got a free coupon code.
# Best Regards,
# Sheikh Mohammad
